# %%
import pymongo
from collections import OrderedDict
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb+srv://analytics:analytics-password@mflix-4ddsu.mongodb.net/test")

pipeline = [
    {
        '$sortByCount': "$language"
    },
    {
        '$facet': {
            'top language combinations': [{'$limit': 100}],
            'unusual combinations shared by': [{
                '$skip': 100
            },
            {
                '$bucketAuto': {
                    'groupBy': "$count",
                    'buckets': 5,
                    'output': {
                        'language combinations': {'$sum': 1}
                    }
                }
            }]
        }
    }
]

clear_output()
pprint.pprint(list(client.mflix.movies_initial.aggregate(pipeline)))
# Out:
# [{'top language combinations': [{'_id': 'English', 'count': 29321},
#                                 {'_id': 'French', 'count': 2021},
#                                 {'_id': 'Italian', 'count': 1643},
#                                 {'_id': 'Japanese', 'count': 1418},
#                                 {'_id': '', 'count': 1346},
#                                 {'_id': 'Spanish', 'count': 935},
#                                 {'_id': 'Russian', 'count': 848},
#                                 {'_id': 'English, Spanish', 'count': 834},
#                                 {'_id': 'German', 'count': 773},
#                                 {'_id': 'English, French', 'count': 740},
#                                 {'_id': 'Hindi', 'count': 506},
#                                 {'_id': 'Korean', 'count': 377},
#                                 {'_id': 'Finnish', 'count': 370},
#                                 {'_id': 'English, German', 'count': 358},
#                                 {'_id': 'English, Italian', 'count': 321},
#                                 {'_id': 'Swedish', 'count': 319},
#                                 {'_id': 'Mandarin', 'count': 289},
#                                 {'_id': 'French, English', 'count': 261},
#                                 {'_id': 'Portuguese', 'count': 261},
#                                 {'_id': 'Polish', 'count': 215},
#                                 {'_id': 'Dutch', 'count': 202},
#                                 {'_id': 'English, Japanese', 'count': 186},
#                                 {'_id': 'English, Russian', 'count': 176},
#                                 {'_id': 'Cantonese', 'count': 170},
#                                 {'_id': 'Danish', 'count': 163},
#                                 {'_id': 'Turkish', 'count': 155},
#                                 {'_id': 'Japanese, English', 'count': 144},
#                                 {'_id': 'Greek', 'count': 121},
#                                 {'_id': 'Czech', 'count': 114},
#                                 {'_id': 'German, English', 'count': 108},
#                                 {'_id': 'Spanish, English', 'count': 102},
#                                 {'_id': 'Persian', 'count': 95},
#                                 {'_id': 'Italian, English', 'count': 94},
#                                 {'_id': 'Norwegian', 'count': 89},
#                                 {'_id': 'Hungarian', 'count': 86},
#                                 {'_id': 'English, French, German', 'count': 77},
#                                 {'_id': 'Hindi, English', 'count': 69},
#                                 {'_id': 'English, Latin', 'count': 68},
#                                 {'_id': 'Thai', 'count': 66},
#                                 {'_id': 'English, Mandarin', 'count': 66},
#                                 {'_id': 'Romanian', 'count': 64},
#                                 {'_id': 'English, Portuguese', 'count': 64},
#                                 {'_id': 'Tamil', 'count': 55},
#                                 {'_id': 'English, Arabic', 'count': 54},
#                                 {'_id': 'English, German, French', 'count': 52},
#                                 {'_id': 'Cantonese, Mandarin', 'count': 51},
#                                 {'_id': 'Cantonese, English', 'count': 50},
#                                 {'_id': 'French, German', 'count': 48},
#                                 {'_id': 'English, Cantonese', 'count': 47},
#                                 {'_id': 'Marathi', 'count': 46},
#                                 {'_id': 'English, French, Spanish',
#                                  'count': 42},
#                                 {'_id': 'Hebrew', 'count': 42},
#                                 {'_id': 'English, Swedish', 'count': 41},
#                                 {'_id': 'English, French, Italian',
#                                  'count': 39},
#                                 {'_id': 'English, Hebrew', 'count': 37},
#                                 {'_id': 'Russian, English', 'count': 37},
#                                 {'_id': 'English, American Sign Language',
#                                  'count': 36},
#                                 {'_id': 'Arabic', 'count': 35},
#                                 {'_id': 'Bengali', 'count': 35},
#                                 {'_id': 'English, Spanish, French',
#                                  'count': 35},
#                                 {'_id': 'Swedish, English', 'count': 35},
#                                 {'_id': 'French, Spanish', 'count': 35},
#                                 {'_id': 'Serbian', 'count': 35},
#                                 {'_id': 'Chinese', 'count': 33},
#                                 {'_id': 'Telugu', 'count': 33},
#                                 {'_id': 'French, Italian', 'count': 32},
#                                 {'_id': 'Russian, German', 'count': 31},
#                                 {'_id': 'English, Yiddish', 'count': 31},
#                                 {'_id': 'Italian, German', 'count': 30},
#                                 {'_id': 'French, Arabic', 'count': 30},
#                                 {'_id': 'Dutch, English', 'count': 30},
#                                 {'_id': 'English, Hindi', 'count': 30},
#                                 {'_id': 'Mandarin, Cantonese', 'count': 30},
#                                 {'_id': 'English, Greek', 'count': 28},
#                                 {'_id': 'English, Vietnamese', 'count': 28},
#                                 {'_id': 'Estonian', 'count': 28},
#                                 {'_id': 'Korean, English', 'count': 27},
#                                 {'_id': 'Malayalam', 'count': 27},
#                                 {'_id': 'English, German, Italian',
#                                  'count': 26},
#                                 {'_id': 'English, Korean', 'count': 26},
#                                 {'_id': 'Italian, Spanish', 'count': 25},
#                                 {'_id': 'French, German, English', 'count': 25},
#                                 {'_id': 'English, German, Russian',
#                                  'count': 24},
#                                 {'_id': 'Icelandic', 'count': 23},
#                                 {'_id': 'English, Italian, French',
#                                  'count': 22},
#                                 {'_id': 'Serbo-Croatian', 'count': 22},
#                                 {'_id': 'Mandarin, English', 'count': 22},
#                                 {'_id': 'Spanish, French', 'count': 22},
#                                 {'_id': 'Finnish, Swedish', 'count': 21},
#                                 {'_id': 'English, Polish', 'count': 21},
#                                 {'_id': 'English, Chinese', 'count': 21},
#                                 {'_id': 'Indonesian', 'count': 20},
#                                 {'_id': 'English, Italian, Spanish',
#                                  'count': 20},
#                                 {'_id': 'English, Dutch', 'count': 20},
#                                 {'_id': 'German, French', 'count': 19},
#                                 {'_id': 'English, Hungarian', 'count': 19},
#                                 {'_id': 'Georgian', 'count': 19},
#                                 {'_id': 'Italian, French', 'count': 19},
#                                 {'_id': 'English, French, Russian',
#                                  'count': 18},
#                                 {'_id': 'Croatian', 'count': 17}],
#   'unusual combinations shared by': [{'_id': {'max': 2, 'min': 1},
#                                       'language combinations': 1788},
#                                      {'_id': {'max': 5, 'min': 2},
#                                       'language combinations': 552},
#                                      {'_id': {'max': 17, 'min': 5},
#                                       'language combinations': 171}]}]
